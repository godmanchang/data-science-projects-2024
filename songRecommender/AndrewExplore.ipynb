# %% [markdown]
# # My Data Science Project

# %%
# Import packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets

# %%
# Load iris dataset
# from load_iris to load_diabetes
data = datasets.load_iris()
df = pd.DataFrame(data['data'])
df.columns = data['feature_names']
df['target'] = data['target']

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
# Supervised learning
# Encoded: 0 = setosa , 1 = versicolor , 2 = virginica
from sklearn.model_selection import train_test_split

x = df.drop(columns = ['target'])
y = df['target']

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=123)

# %%
#Define KNN classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC


# KNNclassifier = KNeighborsClassifier(n_neighbors=3)
LinSVCclassifier = LinearSVC(C=0.1, random_state=123)
#SVM_Model = SVC(kernel="rbf")


#Train classifier

# KNNclassifier.fit(X_train, y_train)
LinSVCclassifier.fit(X_train,y_train)

#SVM_Model.fit(X_train,y_train)
# Out:
# LinearSVC(C=0.1, random_state=123)

# %%
#Predict / test model
#y_pred = KNNclassifier.predict(X_test)
y_pred = LinSVCclassifier.predict(X_test)
#y_pred = SVM_Model.predict(X_test)
test = LinSVCclassifier.c
print(test)
# computed_gamma = SVM_Model._gamma
# print("Computed gamma value:", computed_gamma)
# Out:
# [[ 0.11616699  0.39425967 -0.60992911 -0.29089532]
#  [ 0.19763429 -0.60227685  0.17303822 -0.4806497 ]
#  [-0.58123647 -0.60180584  0.89318143  0.84005053]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 100.00%

# %%
# Plot the confusion matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=data.target_names, yticklabels=data.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
#Linear SVM
#RBF SVM <- try best to learn these 


#kernel SVM

# %%
#Kaggle learning:  intro to machine learning / pandas
