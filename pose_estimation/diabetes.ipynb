# %% [markdown]
# ## Exploratory Data Analysis: Diabetes database

# %%
#import databases
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

#call diabetes database
data = datasets.load_diabetes(scaled=False)
df = pd.DataFrame(data['data'])
df.columns = data['feature_names']
df['target'] = data['target']

# %% [markdown]
# ### Overview of database

# %%
df
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6  target
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0   151.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0    75.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0   141.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0   206.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0   135.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...     ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0   178.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0   104.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0   132.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0   220.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0    57.0
#
# [442 rows x 11 columns]

# %%
df.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                s3          s4          s5          s6      target
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# ...

# %% [markdown]
# ##### Age: Mean, Median, STD

# %%
#(1) Date in MM-DD-YYYY format (2) Time in XX:YY format (3) Code (4) Value
#mean value of age
mean_age = df['age'].mean()
print("The mean age is", mean_age.round(2), "\n")

#median value of age
median_age = df['age'].median()
print("The median age is", median_age, "\n")

#standard deviation of age
std_age = df['age'].std()
print("The std of age is",std_age.round(2), "\n")
# Out:
# The mean age is 48.52
#
# The median age is 50.0
#
# The std of age is 13.11

# %% [markdown]
# ##### Sex: Mean, Median, STD

# %%
#mean of sex
mean_sex = df['sex'].mean()
print("The mean sex is", mean_sex.round(2), "\n")

#median of sex
median_sex = df['sex'].median()
print("The median sex is", median_sex, "\n")

#std of sex
std_sex = df['sex'].std()
print("The mean sex is", std_sex.round(2), "\n")
# Out:
# The mean sex is 1.47
#
# The median sex is 1.0
#
# The mean sex is 0.5

# %% [markdown]
# ##### BMI: Mean, Median, STD

# %%
#mean of BMI
mean_bmi = df['bmi'].mean()
print("The mean BMI is", mean_bmi.round(2), "\n")

#median of BMI
median_bmi = df['bmi'].median()
print("The median BMI is", median_bmi, "\n")

#std of bmi
std_bmi = df['bmi'].std()
print("The std of BMI is", std_bmi.round(2), "\n")
# Out:
# The mean BMI is 26.38
#
# The median BMI is 25.7
#
# The std of BMI is 4.42

# %% [markdown]
# ##### bp: mean, median, std

# %%
#mean of bp
mean_bp = df['bp'].mean()
print("The mean bp is", mean_bp.round(2), "\n")

#median of bp
median_bp = df['bp'].median()
print("The median bp is", median_bp, "\n")

#std of bp
std_bp = df['bp'].std()
print("The std of bp is", std_bp.round(2), "\n")
# Out:
# The mean bp is 94.65
#
# The median bp is 93.0
#
# The std of bp is 13.83

# %% [markdown]
# ### Outliers in the features of the dataset

# %% [markdown]
# #### Outlier age

# %%
sns.boxplot(x='age', y='target', data=df)
# Out:
# <Axes: xlabel='age', ylabel='target'>

# %% [markdown]
# #### Outlier sex

# %%
sns.boxplot(x='sex', y='target', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='target'>

# %% [markdown]
# #### Outlier BMI

# %%
plt.figure(figsize=(30,6))
sns.boxplot(x='target', y='bmi', data=df)
# Out:
# <Axes: xlabel='target', ylabel='bmi'>

# %% [markdown]
# #### Outlier BP

# %%
plt.figure(figsize=(30,6))
sns.boxplot(x='bp', y='target', data=df)
# Out:
# <Axes: xlabel='bp', ylabel='target'>

# %% [markdown]
# ### Histogram for target variable

# %%
df.hist(figsize=(12,8), bins=25)
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)
